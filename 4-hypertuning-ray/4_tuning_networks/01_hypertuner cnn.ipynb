# %% [markdown]
# <td>
# <a href="https://colab.research.google.com/github/raoulg/MADS-MachineLearning-course/blob/master/notebooks/4_tuning_networks/01_hypertuner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
# </td>

# %%
import time
import numpy as np
from plotly import graph_objects as go
import matplotlib.pyplot as plt

from loguru import logger

import ray
from ray import tune

import torch
from torch import optim
from torch import nn

from pathlib import Path

# %matplotlib inline
plt.style.use('dark_background')
# import plotly.io as pio
# pio.renderers.default = 'plotly_mimetype+notebook'

import visualize
DELETE = True # to delete the tunedir at the end of the notebook
start = time.time()

# %% [markdown]
# This is a general reference notebook to explore the use of ray tuner.
# First, we define some global variables. This makes it easier to change the parameters for the full notebook at once and run everything.
#
# Set the max_epochs to something like 10 (this will take longer, but you will get better results), and experiments to 18. This way, you will have a good way to compare gridsearch with the other tuners because gridsearch will do 3 * 6 = 18 experiments.
#
# The reason I am setting this low is because i automated the testing of the notebook and it takes a long time to run all the experiments by default.

# %%
MAX_EPOCHS = 3
N_EXPERIMENTS = 3

# %% [markdown]
# # Train function and config

# %% [markdown]
# Let's define some dicts to log the results of the training.

# %%
timer = {}
best_config = {}

# %% [markdown]
# We will need a training function. This is also implemented in the mltrainer, but I put it here to show you how the details work.

# %%
def train_fn(model, trainstreamer, lossfn, optimizer, steps):
    model.train()
    train_loss: float = 0.0
    for _ in range(steps):
        x, y = next(trainstreamer)
        #x = x.unsqueeze(1)  # [B, H, W] -> [B, 1, H, W] extra dimensie toevoegen
        optimizer.zero_grad()
        yhat = model(x)
        loss = lossfn(yhat, y)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
    return train_loss

# %% [markdown]
# We validate on the validation set and return the loss.

# %%
def validate(model, validstreamer, lossfn, metric, steps):
    model.eval()
    valid_loss: float = 0.0
    acc: float = 0.0
    with torch.no_grad():
        for _ in range(steps):
            x, y = next(validstreamer)
           # x = x.unsqueeze(1)  # [B, H, W] -> [B, 1, H, W]
            yhat = model(x)
            loss = lossfn(yhat, y)
            valid_loss += loss.item()
            acc += metric(y, yhat)
    acc /= steps
    return valid_loss, acc

# %% [markdown]
# Getting the data requires a bit extra care. Because we will run experiments in parallel on all the cpu's available, we well use FileLock to make sure that loading the data does not conflict.
#
# Note we import functions inside the function we will later on pass to ray. This is because ray will serialize the function and send it to the workers. If we import the functions outside the function, the workers will not have access to them.

# %%
def get_data(tune_dir):
    from filelock import FileLock
    tune_dir = Path(tune_dir)   # <-- toevoegen
    from mads_datasets import DatasetFactoryProvider, DatasetType
    from mltrainer.preprocessors import PaddedPreprocessor
    from mads_datasets import DatasetFactoryProvider, DatasetType
    with FileLock(tune_dir / ".lock"):
        # we lock the datadir to avoid parallel instances trying to
        # access the datadir
        preprocessor = PaddedPreprocessor()
        gesturesdatasetfactory = DatasetFactoryProvider.create_factory(DatasetType.FASHION)
        streamers = gesturesdatasetfactory.create_datastreamer(
            batchsize=32, preprocessor=preprocessor
        )
        train = streamers["train"]
        valid = streamers["valid"]
    return train, valid

# %% [markdown]
# We will use the same GRU model we used last lesson. You might improve this in a few ways (eg consider adding skip layers, conv1d, etc) but for clarity, lets keep it simple.

# %%
class GRUmodel(nn.Module):
    def __init__(
        self,
        config: dict,
    ) -> None:
        super().__init__()
        self.rnn = nn.GRU(
            input_size=config["input_size"],
            hidden_size=int(config["hidden_size"]),
            dropout=config["dropout"],
            batch_first=True,
            num_layers=int(config["num_layers"]),
        )
        self.linear = nn.Linear(int(config["hidden_size"]), config["output_size"])

    def forward(self, x):
        x, _ = self.rnn(x)
        last_step = x[:, -1, :]
        yhat = self.linear(last_step)
        return yhat

# %%
class CNN(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.input_size = config.get("input_size", (1, 1, 28, 28))  # (B, C, H, W) met B=1 voor test
        self.in_channels = self.input_size[1]
        self.filters = int(config["filters"])
        self.units1 = int(config["units1"])
        self.units2 = int(config["units2"])

        self.convolutions = nn.Sequential(
            nn.Conv2d(self.in_channels, self.filters, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2),
            nn.Conv2d(self.filters, self.filters, kernel_size=3, stride=1, padding=0),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2),
            nn.Conv2d(self.filters, self.filters, kernel_size=3, stride=1, padding=0),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2),
        )

        activation_map_size = self._conv_test(self.input_size)
        # logger.info(f"Aggregating activationmap with size {activation_map_size}")
        print(f"Aggregating activationmap with size {activation_map_size}")

        self.agg = nn.AvgPool2d(activation_map_size)

        self.dense = nn.Sequential(
            nn.Flatten(),
            nn.Linear(self.filters, self.units1),
            nn.ReLU(),
            nn.Linear(self.units1, self.units2),
            nn.ReLU(),
            nn.Linear(self.units2, 10)  # Fashion = 10 klassen
        )

    def _conv_test(self, input_size):
        x = torch.ones(input_size, dtype=torch.float32)
        x = self.convolutions(x)
        return x.shape[-2:]

    def forward(self, x):
        x = self.convolutions(x)
        x = self.agg(x)
        logits = self.dense(x)
        return logits

# %% [markdown]
# Now, we have all the ingredients we need to run the tuner.
# We create a function that:
# - loads the data with a lock
# - creates the model
# - trains the model
# - validates the model
# - reports the results to ray

# %%
#def tune_model(config: dict):
def tune_model(config):
    from mltrainer.metrics import Accuracy

    # load data
    train, valid = get_data(config["tune_dir"])
    trainsteps = len(train)
    validsteps = len(valid)
    trainstreamer = train.stream()
    validstreamer = valid.stream()

    # create model with config
    #model = GRUmodel(config)
    #model = CNN
    #model = CNN(config["filters"], config["units1"], config["units2"], (1, 1, 28, 28))
    model = CNN(config)
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    loss_fn = torch.nn.CrossEntropyLoss()
    metric = Accuracy()

    for _ in range(config["epochs"]):
        # train and validate
        train_loss = train_fn(model, trainstreamer, loss_fn, optimizer, trainsteps)
        valid_loss, accuracy = validate(model, validstreamer, loss_fn, metric, validsteps)

        # report to ray
        ray.train.report({
            "valid_loss": valid_loss / validsteps,
            "train_loss": train_loss / trainsteps,
            "accuracy" : accuracy,
            })

# %% [markdown]
# Let's try this, to see if everything works as expected.
# Note that it typically does not make sense to use accelaration here; we will typically have 1 GPU, but 10 or 16 CPUS. We gain much more from parallelizing the experiments than we gain by running the model faster on a single GPU.

# %%
tune_dir = Path("logs/test/").resolve()

# %%
#in_channels=in_channels,
#   out_channels=64,
#    kernel_size=3,
#    padding=(1,1),
#    stride=2)

# %%
config = {
    #"input_size": 3,
    #"output_size": 20,
    #"dropout": 0.1,
    #"hidden_size": 64,
    #"num_layers": 2,
    "epochs": MAX_EPOCHS,
    #"tune_dir": tune_dir,
    "filters": 32,
    "units1": 128,
    "units2": 64,
    "tune_dir": str(tune_dir),
}
#tune_model(config)

# %% [markdown]
# # Key concepts
#
# In the ray documentation https://docs.ray.io/en/latest/tune/key-concepts.html#tune-search-spaces you can find an overview of all the types of search spaces. I will copy an example here
#
# ```python
# config = {
#     "uniform": tune.uniform(-5, -1),  # Uniform float between -5 and -1
#     "quniform": tune.quniform(3.2, 5.4, 0.2),  # Round to multiples of 0.2
#     "loguniform": tune.loguniform(1e-4, 1e-1),  # Uniform float in log space
#     "qloguniform": tune.qloguniform(1e-4, 1e-1, 5e-5),  # Round to multiples of 0.00005
#     "randn": tune.randn(10, 2),  # Normal distribution with mean 10 and sd 2
#     "qrandn": tune.qrandn(10, 2, 0.2),  # Round to multiples of 0.2
#     "randint": tune.randint(-9, 15),  # Random integer between -9 and 15
#     "qrandint": tune.qrandint(-21, 12, 3),  # Round to multiples of 3 (includes 12)
#     "lograndint": tune.lograndint(1, 10),  # Random integer in log space
#     "qlograndint": tune.qlograndint(1, 10, 2),  # Round to multiples of 2
#     "choice": tune.choice(["a", "b", "c"]),  # Choose one of these options uniformly
#     "func": tune.sample_from(
#         lambda spec: spec.config.uniform * 0.01
#     ),  # Depends on other value
#     "grid": tune.grid_search([32, 64, 128]),  # Search over all these values
# }
# ```
# but in the docs you can find more details about every option

# %% [markdown]
# # Random search

# %% [markdown]
# Now, let's do a random search.
#
# First, we define the search space. We can specify specific values, but also distributions.
# For the hidden size, we will use randint, which will sample from a uniform distribution of integers.
# The same for the number of layers.
#
# The `tune.run` function runs the hypertuning. It will sample from the search space, and create a specific config for each experiment.

# %%
config = {
   # "input_size": 3,
   # "output_size": 20,
   # "dropout": 0.05,
    "epochs": MAX_EPOCHS,
   # "hidden_size": tune.randint(16, 512),
   # "num_layers": tune.randint(1, 8),
    "tune_dir": tune_dir,
    #"filters": 32,
    "filters": tune.randint(2,16),
    "units1": 128,
    "units2": 64,
}

# %% [markdown]
# Let's test this!

# %%
tic = time.time()
analysis = tune.run(
    tune_model,
    config=config,
    metric="valid_loss",
    mode="min",
    storage_path=str(tune_dir),
    num_samples=N_EXPERIMENTS,
    stop={"training_iteration": MAX_EPOCHS},
    verbose=1,
)

timer["ray_random"] = time.time() - tic
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2025-10-18 15:14:17</td></tr>
# <tr><td>Running for: </td><td>00:01:50.06        </td></tr>
# <tr><td>Memory:      </td><td>3.6/15.6 GiB       </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 1.0/2 CPUs, 0/0 GPUs
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name            </th><th>status    </th><th>loc                 </th><th style="text-align: right;">  filters</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  valid_loss</th><th style="text-align: right;">  train_loss</th><th style="text-align: right;">  accuracy</th></tr>
# </thead>
# <tbody>
# <tr><td>tune_model_1806e_00000</td><td>TERMINATED</td><td>192.168.3.171:175109</td><td style="text-align: right;">        8</td><td style="text-align: right;">     3</td><td style="text-align: right;">         44.6373</td><td style="text-align: right;">    0.635493</td><td style="text-align: right;">    0.657007</td><td style="text-align: right;">  0.760417</td></tr>
# <tr><td>tune_model_1806e_00001</td><td>TERMINATED</td><td>192.168.3.171:175110</td><td style="text-align: right;">       11</td><td style="text-align: right;">     3</td><td style="text-align: right;">         59.4775</td><td style="text-align: right;">    0.502738</td><td style="text-align: right;">    0.517215</td><td style="text-align: right;">  0.816406</td></tr>
# <tr><td>tune_model_1806e_00002</td><td>TERMINATED</td><td>192.168.3.171:177273</td><td style="text-align: right;">       12</td><td style="text-align: right;">     3</td><td style="text-align: right;">         57.7242</td><td style="text-align: right;">    0.505003</td><td style="text-align: right;">    0.521224</td><td style="text-align: right;">  0.817007</td></tr>
# </tbody>
# </table>
#   </div>
# </div>
# <style>
# .tuneStatus {
#   color: var(--jp-ui-font-color1);
# }
# .tuneStatus .systemInfo {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus td {
#   white-space: nowrap;
# }
# .tuneStatus .trialStatus {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus h3 {
#   font-weight: bold;
# }
# .tuneStatus .hDivider {
#   border-bottom-width: var(--jp-border-width);
#   border-bottom-color: var(--jp-border-color0);
#   border-bottom-style: solid;
# }
# .tuneStatus .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
# (tune_model pid=175110) 2025-10-18 15:12:31.735 | INFO     | mads_datasets.base:download_data:121 - Folder already exists at /home/kkisteman/.cache/mads_datasets/fashionmnist
# (tune_model pid=175110) 2025-10-18 15:12:31.735 | INFO     | mads_datasets.base:download_data:124 - File already exists at /home/kkisteman/.cache/mads_datasets/fashionmnist/fashionmnist.pt
# (tune_model pid=175110) Aggregating activationmap with size torch.Size([2, 2])
# (tune_model pid=175109) /home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (tune_model pid=175109)   _log_deprecation_warning(
# (tune_model pid=175109) 2025-10-18 15:12:31.813 | INFO     | mads_datasets.base:download_data:121 - Folder already exists at /home/kkisteman/.cache/mads_datasets/fashionmnist
# (tune_model pid=175109) 2025-10-18 15:12:31.813 | INFO     | mads_datasets.base:download_data:124 - File already exists at /home/kkisteman/.cache/mads_datasets/fashionmnist/fashionmnist.pt
# (tune_model pid=177273) 2025-10-18 15:13:20.689 | INFO     | mads_datasets.base:download_data:121 - Folder already exists at /home/kkisteman/.cache/mads_datasets/fashionmnist
# (tune_model pid=177273) 2025-10-18 15:13:20.689 | INFO     | mads_datasets.base:download_data:124 - File already exists at /home/kkisteman/.cache/mads_datasets/fashionmnist/fashionmnist.pt
# (tune_model pid=175110) /home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (tune_model pid=175110)   _log_deprecation_warning(
# (tune_model pid=177273) Aggregating activationmap with size torch.Size([2, 2]) [repeated 2x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (tune_model pid=177273) /home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (tune_model pid=177273)   _log_deprecation_warning(
# 2025-10-18 15:14:17,109	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/home/kkisteman/MADS-MachineLearning-course/notebooks/4_tuning_networks/logs/test/tune_model_2025-10-18_15-12-27' in 0.0093s.
# 2025-10-18 15:14:17,114	INFO tune.py:1041 -- Total run time: 110.09 seconds (110.05 seconds for the tuning loop).
# (tune_model pid=179463) 2025-10-18 15:14:22.985 | INFO     | mads_datasets.base:download_data:121 - Folder already exists at /home/kkisteman/.cache/mads_datasets/fashionmnist
# (tune_model pid=179463) 2025-10-18 15:14:22.985 | INFO     | mads_datasets.base:download_data:124 - File already exists at /home/kkisteman/.cache/mads_datasets/fashionmnist/fashionmnist.pt
# (tune_model pid=179642) 2025-10-18 15:14:29.161 | INFO     | mads_datasets.base:download_data:121 - Folder already exists at /home/kkisteman/.cache/mads_datasets/fashionmnist [repeated 2x across cluster]
# (tune_model pid=179642) 2025-10-18 15:14:29.161 | INFO     | mads_datasets.base:download_data:124 - File already exists at /home/kkisteman/.cache/mads_datasets/fashionmnist/fashionmnist.pt [repeated 2x across cluster]
# (tune_model pid=179809) 2025-10-18 15:14:35.059 | INFO     | mads_datasets.base:download_data:121 - Folder already exists at /home/kkisteman/.cache/mads_datasets/fashionmnist [repeated 2x across cluster]
# (tune_model pid=179809) 2025-10-18 15:14:35.060 | INFO     | mads_datasets.base:download_data:124 - File already exists at /home/kkisteman/.cache/mads_datasets/fashionmnist/fashionmnist.pt [repeated 2x across cluster]
# (tune_model pid=179963) 2025-10-18 15:14:40.419 | INFO     | mads_datasets.base:download_data:121 - Folder already exists at /home/kkisteman/.cache/mads_datasets/fashionmnist [repeated 2x across cluster]
# (tune_model pid=179963) 2025-10-18 15:14:40.419 | INFO     | mads_datasets.base:download_data:124 - File already exists at /home/kkisteman/.cache/mads_datasets/fashionmnist/fashionmnist.pt [repeated 2x across cluster]

# %%
def plot_contour(df, x, y, z, start=0.90, end=1.0, size=0.01):
    fig = go.Figure()

    fig.add_trace(
        go.Contour(
            z=df[z],
            x=df[x],
            y=df[y],
            contours=dict(
                coloring='heatmap',
                showlabels=True,  # show labels on contours
                start=start,       # start of the contour range
                end=end,          # end of the contour range
                size=size,
            ),
            colorscale="plasma",
            colorbar=dict(
                title='Accuracy'
            )
        )
    )

    fig.add_trace(
        go.Scatter(
            x=df[x],
            y=df[y],
            mode='markers',
            marker=dict(
                color='black',
                size=8,
                symbol='circle'
            ),
            customdata=df['accuracy'],  # Pass accuracy values for hover text
            hovertemplate=(
                'units1: %{x}<br>'
                'filters: %{y}<br>'
                'Accuracy: %{customdata:.4f}<extra></extra>'
            ),
            name='Data Points'
        )
    )

    fig.update_layout(
        title="Contour Plot",
        xaxis_title="units1",
        yaxis_title="filters",
        xaxis=dict(showgrid=False),  # Remove x-axis grid lines
        yaxis=dict(showgrid=False),
        plot_bgcolor='white',        # Set background color to white
        paper_bgcolor='white'
    )

    fig.show()

# %%
all_results = analysis.results_df

# %%
random = analysis.results_df
plot_contour(random, "config/filters", "config/units1", "accuracy")

# %% [markdown]
# As you can see, the search space is sort of randomly sampled.
# Even though big parts are unexplored, it still looks like we find some hotspots.

# %%
best = analysis.get_best_config()
best["accuracy"] = analysis.best_result["accuracy"]
best_config["random"] = best

# %% [markdown]
# So, we searched the hyperparameter space. Problem is, these spaces potentially can get
# pretty big. Let's imagine you have 10 hyperparameters, and every hyperparameter has 5
# possible (relevant) values, you already have $5^{10}$ possible combinations, which is almost 10 million. Even if checking of every configuration would take just 1 second, it would take more than a 100 days to check them all...This
# space can grow out of control pretty fast.
#
# Lets look at the best results we found.

# %%
best
# Out:
# {'epochs': 3,
#  'tune_dir': PosixPath('/home/kkisteman/MADS-MachineLearning-course/notebooks/4_tuning_networks/logs/test'),
#  'filters': 11,
#  'units1': 128,
#  'units2': 64,
#  'accuracy': 0.81640625}

# %%
columns = ["config/filters", "config/units1", "accuracy"]
visualize.parallel_plot(analysis, columns)

# %% [markdown]
# Note how the mean scores are sort of randomly distributed. This is a direct
# effect of random guessing parameters.

# %% [markdown]
# # Grid search

# %% [markdown]
# We can do this more rigorous with a gridsearch.
# The upside of this technique is that you will test every configuration.
#
# A huge downside is the inefficiency. Also, you will run experiments with combinations that might be not very promising, but very slow, which is pretty inefficient.
#
#
# One way to handle this is to use doubling as a strategy to scan the range: 16, 32, ..., 512. This is a bit more efficient.
#
# Typically, this can be a good idea for a first scan, to get a rough idea of the space.
# After you have done this, you can narrow your searchspace, and do a more fine grained search zoomed in on areas that seem promising.

# %%
config = {
    "input_size": 3,
    "output_size": 20,
    "dropout": 0.1,
    "epochs": MAX_EPOCHS,
    "hidden_size": tune.grid_search([16, 32, 64, 128, 256, 512]),
    "num_layers": tune.grid_search([2, 4, 8]),
    "tune_dir": tune_dir,
}

# %%
tic = time.time()

analysis = tune.run(
    tune_model,
    config=config,
    metric="valid_loss",
    mode="min",
    storage_path=str(tune_dir),
    stop={"training_iteration": MAX_EPOCHS},
    verbose=1,
)

timer["ray_grid"] = time.time() - tic

best = analysis.get_best_config()
best["accuracy"] = analysis.best_result["accuracy"]
best_config["grid"] = best
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2025-10-18 15:14:40</td></tr>
# <tr><td>Running for: </td><td>00:00:23.08        </td></tr>
# <tr><td>Memory:      </td><td>3.9/15.6 GiB       </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 1.0/2 CPUs, 0/0 GPUs
#     </div>
#     <div class="vDivider"></div>
# <div class="messages">
#   <h3>Messages</h3>
#
#
#   Number of errored trials: 7<br><table>
# <thead>
# <tr><th>Trial name            </th><th style="text-align: right;">  # failures</th><th>error file                                                                                                                                                                                                          </th></tr>
# </thead>
# <tbody>
# <tr><td>tune_model_59e62_00000</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2025-10-18_15-12-24_515152_174805/artifacts/2025-10-18_15-14-17/tune_model_2025-10-18_15-14-17/driver_artifacts/tune_model_59e62_00000_0_hidden_size=16,num_layers=2_2025-10-18_15-14-17/error.txt </td></tr>
# <tr><td>tune_model_59e62_00001</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2025-10-18_15-12-24_515152_174805/artifacts/2025-10-18_15-14-17/tune_model_2025-10-18_15-14-17/driver_artifacts/tune_model_59e62_00001_1_hidden_size=32,num_layers=2_2025-10-18_15-14-17/error.txt </td></tr>
# <tr><td>tune_model_59e62_00002</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2025-10-18_15-12-24_515152_174805/artifacts/2025-10-18_15-14-17/tune_model_2025-10-18_15-14-17/driver_artifacts/tune_model_59e62_00002_2_hidden_size=64,num_layers=2_2025-10-18_15-14-17/error.txt </td></tr>
# <tr><td>tune_model_59e62_00003</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2025-10-18_15-12-24_515152_174805/artifacts/2025-10-18_15-14-17/tune_model_2025-10-18_15-14-17/driver_artifacts/tune_model_59e62_00003_3_hidden_size=128,num_layers=2_2025-10-18_15-14-17/error.txt</td></tr>
# <tr><td>tune_model_59e62_00004</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2025-10-18_15-12-24_515152_174805/artifacts/2025-10-18_15-14-17/tune_model_2025-10-18_15-14-17/driver_artifacts/tune_model_59e62_00004_4_hidden_size=256,num_layers=2_2025-10-18_15-14-17/error.txt</td></tr>
# <tr><td>tune_model_59e62_00005</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2025-10-18_15-12-24_515152_174805/artifacts/2025-10-18_15-14-17/tune_model_2025-10-18_15-14-17/driver_artifacts/tune_model_59e62_00005_5_hidden_size=512,num_layers=2_2025-10-18_15-14-17/error.txt</td></tr>
# <tr><td>tune_model_59e62_00006</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2025-10-18_15-12-24_515152_174805/artifacts/2025-10-18_15-14-17/tune_model_2025-10-18_15-14-17/driver_artifacts/tune_model_59e62_00006_6_hidden_size=16,num_layers=4_2025-10-18_15-14-17/error.txt </td></tr>
# </tbody>
# </table>
# </div>
# <style>
# .messages {
#   color: var(--jp-ui-font-color1);
#   display: flex;
#   flex-direction: column;
#   padding-left: 1em;
#   overflow-y: auto;
# }
# .messages h3 {
#   font-weight: bold;
# }
# .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name            </th><th>status  </th><th>loc                 </th><th style="text-align: right;">  hidden_size</th><th style="text-align: right;">  num_layers</th></tr>
# </thead>
# <tbody>
# <tr><td>tune_model_59e62_00007</td><td>RUNNING </td><td>192.168.3.171:179965</td><td style="text-align: right;">           32</td><td style="text-align: right;">           4</td></tr>
# <tr><td>tune_model_59e62_00008</td><td>PENDING </td><td>                    </td><td style="text-align: right;">           64</td><td style="text-align: right;">           4</td></tr>
# <tr><td>tune_model_59e62_00009</td><td>PENDING </td><td>                    </td><td style="text-align: right;">          128</td><td style="text-align: right;">           4</td></tr>
# <tr><td>tune_model_59e62_00010</td><td>PENDING </td><td>                    </td><td style="text-align: right;">          256</td><td style="text-align: right;">           4</td></tr>
# <tr><td>tune_model_59e62_00011</td><td>PENDING </td><td>                    </td><td style="text-align: right;">          512</td><td style="text-align: right;">           4</td></tr>
# <tr><td>tune_model_59e62_00012</td><td>PENDING </td><td>                    </td><td style="text-align: right;">           16</td><td style="text-align: right;">           8</td></tr>
# <tr><td>tune_model_59e62_00013</td><td>PENDING </td><td>                    </td><td style="text-align: right;">           32</td><td style="text-align: right;">           8</td></tr>
# <tr><td>tune_model_59e62_00014</td><td>PENDING </td><td>                    </td><td style="text-align: right;">           64</td><td style="text-align: right;">           8</td></tr>
# <tr><td>tune_model_59e62_00015</td><td>PENDING </td><td>                    </td><td style="text-align: right;">          128</td><td style="text-align: right;">           8</td></tr>
# <tr><td>tune_model_59e62_00016</td><td>PENDING </td><td>                    </td><td style="text-align: right;">          256</td><td style="text-align: right;">           8</td></tr>
# <tr><td>tune_model_59e62_00017</td><td>PENDING </td><td>                    </td><td style="text-align: right;">          512</td><td style="text-align: right;">           8</td></tr>
# <tr><td>tune_model_59e62_00000</td><td>ERROR   </td><td>192.168.3.171:179463</td><td style="text-align: right;">           16</td><td style="text-align: right;">           2</td></tr>
# <tr><td>tune_model_59e62_00001</td><td>ERROR   </td><td>192.168.3.171:179491</td><td style="text-align: right;">           32</td><td style="text-align: right;">           2</td></tr>
# <tr><td>tune_model_59e62_00002</td><td>ERROR   </td><td>192.168.3.171:179642</td><td style="text-align: right;">           64</td><td style="text-align: right;">           2</td></tr>
# <tr><td>tune_model_59e62_00003</td><td>ERROR   </td><td>192.168.3.171:179644</td><td style="text-align: right;">          128</td><td style="text-align: right;">           2</td></tr>
# <tr><td>tune_model_59e62_00004</td><td>ERROR   </td><td>192.168.3.171:179806</td><td style="text-align: right;">          256</td><td style="text-align: right;">           2</td></tr>
# <tr><td>tune_model_59e62_00005</td><td>ERROR   </td><td>192.168.3.171:179809</td><td style="text-align: right;">          512</td><td style="text-align: right;">           2</td></tr>
# <tr><td>tune_model_59e62_00006</td><td>ERROR   </td><td>192.168.3.171:179963</td><td style="text-align: right;">           16</td><td style="text-align: right;">           4</td></tr>
# </tbody>
# </table>
#   </div>
# </div>
# <style>
# .tuneStatus {
#   color: var(--jp-ui-font-color1);
# }
# .tuneStatus .systemInfo {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus td {
#   white-space: nowrap;
# }
# .tuneStatus .trialStatus {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus h3 {
#   font-weight: bold;
# }
# .tuneStatus .hDivider {
#   border-bottom-width: var(--jp-border-width);
#   border-bottom-color: var(--jp-border-color0);
#   border-bottom-style: solid;
# }
# .tuneStatus .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
# 2025-10-18 15:14:23,059	ERROR tune_controller.py:1331 -- Trial task failed for trial tune_model_59e62_00000
# Traceback (most recent call last):
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#              ^^^^^^^^^^^^^^^
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/_private/worker.py", line 2822, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/_private/worker.py", line 930, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TypeError): ray::ImplicitFunc.train() (pid=179463, ip=192.168.3.171, actor_id=c43f5e4f833f9f4fd01a44eb01000000, repr=tune_model)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/tune/trainable/trainable.py", line 330, in train
#     raise skipped from exception_cause(skipped)
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/air/_internal/util.py", line 107, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/tune/trainable/function_trainable.py", line 261, in _trainable_func
#     output = fn()
#              ^^^^
#   File "/tmp/ipykernel_174805/1246840893.py", line 16, in tune_model
#   File "/tmp/ipykernel_174805/872125694.py", line 5, in __init__
# TypeError: 'int' object is not subscriptable
# 2025-10-18 15:14:23,298	ERROR tune_controller.py:1331 -- Trial task failed for trial tune_model_59e62_00001
# Traceback (most recent call last):
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#              ^^^^^^^^^^^^^^^
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/_private/worker.py", line 2822, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/_private/worker.py", line 930, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TypeError): ray::ImplicitFunc.train() (pid=179491, ip=192.168.3.171, actor_id=9a01ab9a722ae0adef4925e601000000, repr=tune_model)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/tune/trainable/trainable.py", line 330, in train
#     raise skipped from exception_cause(skipped)
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/air/_internal/util.py", line 107, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/tune/trainable/function_trainable.py", line 261, in _trainable_func
#     output = fn()
#              ^^^^
#   File "/tmp/ipykernel_174805/1246840893.py", line 16, in tune_model
#   File "/tmp/ipykernel_174805/872125694.py", line 5, in __init__
# TypeError: 'int' object is not subscriptable
# 2025-10-18 15:14:29,298	ERROR tune_controller.py:1331 -- Trial task failed for trial tune_model_59e62_00003
# Traceback (most recent call last):
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#              ^^^^^^^^^^^^^^^
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/_private/worker.py", line 2822, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/_private/worker.py", line 930, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TypeError): ray::ImplicitFunc.train() (pid=179644, ip=192.168.3.171, actor_id=7c7a51bd31e56633bda6319f01000000, repr=tune_model)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/tune/trainable/trainable.py", line 330, in train
#     raise skipped from exception_cause(skipped)
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/air/_internal/util.py", line 107, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/tune/trainable/function_trainable.py", line 261, in _trainable_func
#     output = fn()
#              ^^^^
#   File "/tmp/ipykernel_174805/1246840893.py", line 16, in tune_model
#   File "/tmp/ipykernel_174805/872125694.py", line 5, in __init__
# TypeError: 'int' object is not subscriptable
# 2025-10-18 15:14:29,374	ERROR tune_controller.py:1331 -- Trial task failed for trial tune_model_59e62_00002
# Traceback (most recent call last):
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#              ^^^^^^^^^^^^^^^
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/_private/worker.py", line 2822, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/_private/worker.py", line 930, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TypeError): ray::ImplicitFunc.train() (pid=179642, ip=192.168.3.171, actor_id=eff1af41bb1df4ae6cf1a8f401000000, repr=tune_model)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/tune/trainable/trainable.py", line 330, in train
#     raise skipped from exception_cause(skipped)
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/air/_internal/util.py", line 107, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/tune/trainable/function_trainable.py", line 261, in _trainable_func
#     output = fn()
#              ^^^^
#   File "/tmp/ipykernel_174805/1246840893.py", line 16, in tune_model
#   File "/tmp/ipykernel_174805/872125694.py", line 5, in __init__
# TypeError: 'int' object is not subscriptable
# 2025-10-18 15:14:35,175	ERROR tune_controller.py:1331 -- Trial task failed for trial tune_model_59e62_00005
# Traceback (most recent call last):
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#              ^^^^^^^^^^^^^^^
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/_private/worker.py", line 2822, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/_private/worker.py", line 930, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TypeError): ray::ImplicitFunc.train() (pid=179809, ip=192.168.3.171, actor_id=2eed0963e6ba93820e6fc20501000000, repr=tune_model)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/tune/trainable/trainable.py", line 330, in train
#     raise skipped from exception_cause(skipped)
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/air/_internal/util.py", line 107, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/tune/trainable/function_trainable.py", line 261, in _trainable_func
#     output = fn()
#              ^^^^
#   File "/tmp/ipykernel_174805/1246840893.py", line 16, in tune_model
#   File "/tmp/ipykernel_174805/872125694.py", line 5, in __init__
# TypeError: 'int' object is not subscriptable
# 2025-10-18 15:14:35,213	ERROR tune_controller.py:1331 -- Trial task failed for trial tune_model_59e62_00004
# Traceback (most recent call last):
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#              ^^^^^^^^^^^^^^^
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/_private/worker.py", line 2822, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/_private/worker.py", line 930, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TypeError): ray::ImplicitFunc.train() (pid=179806, ip=192.168.3.171, actor_id=c32fd9091e35ef39fad62e9c01000000, repr=tune_model)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/tune/trainable/trainable.py", line 330, in train
#     raise skipped from exception_cause(skipped)
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/air/_internal/util.py", line 107, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/tune/trainable/function_trainable.py", line 261, in _trainable_func
#     output = fn()
#              ^^^^
#   File "/tmp/ipykernel_174805/1246840893.py", line 16, in tune_model
#   File "/tmp/ipykernel_174805/872125694.py", line 5, in __init__
# TypeError: 'int' object is not subscriptable
# 2025-10-18 15:14:40,499	ERROR tune_controller.py:1331 -- Trial task failed for trial tune_model_59e62_00006
# Traceback (most recent call last):
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#              ^^^^^^^^^^^^^^^
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/_private/worker.py", line 2822, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/_private/worker.py", line 930, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TypeError): ray::ImplicitFunc.train() (pid=179963, ip=192.168.3.171, actor_id=8141eed4a34571ac1b08aacf01000000, repr=tune_model)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/tune/trainable/trainable.py", line 330, in train
#     raise skipped from exception_cause(skipped)
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/air/_internal/util.py", line 107, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/tune/trainable/function_trainable.py", line 261, in _trainable_func
#     output = fn()
#              ^^^^
#   File "/tmp/ipykernel_174805/1246840893.py", line 16, in tune_model
#   File "/tmp/ipykernel_174805/872125694.py", line 5, in __init__
# TypeError: 'int' object is not subscriptable
# 2025-10-18 15:14:40,618	WARNING tune.py:219 -- Stop signal received (e.g. via SIGINT/Ctrl+C), ending Ray Tune run. This will try to checkpoint the experiment state one last time. Press CTRL+C (or send SIGINT/SIGKILL/SIGTERM) to skip.
# 2025-10-18 15:14:40,636	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/home/kkisteman/MADS-MachineLearning-course/notebooks/4_tuning_networks/logs/test/tune_model_2025-10-18_15-14-17' in 0.0171s.
# 2025-10-18 15:14:40,884	ERROR worker.py:421 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::ImplicitFunc.train() (pid=179965, ip=192.168.3.171, actor_id=211c6886ae324fe8d1b8ddfa01000000, repr=tune_model)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/tune/trainable/trainable.py", line 330, in train
#     raise skipped from exception_cause(skipped)
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/air/_internal/util.py", line 107, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kkisteman/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/tune/trainable/function_trainable.py", line 261, in _trainable_func
#     output = fn()
#              ^^^^
#   File "/tmp/ipykernel_174805/1246840893.py", line 16, in tune_model
#   File "/tmp/ipykernel_174805/872125694.py", line 5, in __init__
# TypeError: 'int' object is not subscriptable
# 2025-10-18 15:14:40,893	ERROR tune.py:1037 -- Trials did not complete: [tune_model_59e62_00000, tune_model_59e62_00001, tune_model_59e62_00002, tune_model_59e62_00003, tune_model_59e62_00004, tune_model_59e62_00005, tune_model_59e62_00006]
# 2025-10-18 15:14:40,897	INFO tune.py:1041 -- Total run time: 23.35 seconds (23.06 seconds for the tuning loop).
# 2025-10-18 15:14:40,897	WARNING tune.py:1056 -- Experiment has been interrupted, but the most recent state was saved.
# Resume experiment with: tune.run(..., resume=True)
# 2025-10-18 15:14:40,909	WARNING experiment_analysis.py:180 -- Failed to fetch metrics for 10 trial(s):
# - tune_model_59e62_00008: FileNotFoundError('Could not fetch metrics for tune_model_59e62_00008: both result.json and progress.csv were not found at /home/kkisteman/MADS-MachineLearning-course/notebooks/4_tuning_networks/logs/test/tune_model_2025-10-18_15-14-17/tune_model_59e62_00008_8_hidden_size=64,num_layers=4_2025-10-18_15-14-17')
# - tune_model_59e62_00009: FileNotFoundError('Could not fetch metrics for tune_model_59e62_00009: both result.json and progress.csv were not found at /home/kkisteman/MADS-MachineLearning-course/notebooks/4_tuning_networks/logs/test/tune_model_2025-10-18_15-14-17/tune_model_59e62_00009_9_hidden_size=128,num_layers=4_2025-10-18_15-14-17')
# - tune_model_59e62_00010: FileNotFoundError('Could not fetch metrics for tune_model_59e62_00010: both result.json and progress.csv were not found at /home/kkisteman/MADS-MachineLearning-course/notebooks/4_tuning_networks/logs/test/tune_model_2025-10-18_15-14-17/tune_model_59e62_00010_10_hidden_size=256,num_layers=4_2025-10-18_15-14-17')
# - tune_model_59e62_00011: FileNotFoundError('Could not fetch metrics for tune_model_59e62_00011: both result.json and progress.csv were not found at /home/kkisteman/MADS-MachineLearning-course/notebooks/4_tuning_networks/logs/test/tune_model_2025-10-18_15-14-17/tune_model_59e62_00011_11_hidden_size=512,num_layers=4_2025-10-18_15-14-17')
# - tune_model_59e62_00012: FileNotFoundError('Could not fetch metrics for tune_model_59e62_00012: both result.json and progress.csv were not found at /home/kkisteman/MADS-MachineLearning-course/notebooks/4_tuning_networks/logs/test/tune_model_2025-10-18_15-14-17/tune_model_59e62_00012_12_hidden_size=16,num_layers=8_2025-10-18_15-14-17')
# - tune_model_59e62_00013: FileNotFoundError('Could not fetch metrics for tune_model_59e62_00013: both result.json and progress.csv were not found at /home/kkisteman/MADS-MachineLearning-course/notebooks/4_tuning_networks/logs/test/tune_model_2025-10-18_15-14-17/tune_model_59e62_00013_13_hidden_size=32,num_layers=8_2025-10-18_15-14-17')
# - tune_model_59e62_00014: FileNotFoundError('Could not fetch metrics for tune_model_59e62_00014: both result.json and progress.csv were not found at /home/kkisteman/MADS-MachineLearning-course/notebooks/4_tuning_networks/logs/test/tune_model_2025-10-18_15-14-17/tune_model_59e62_00014_14_hidden_size=64,num_layers=8_2025-10-18_15-14-17')
# - tune_model_59e62_00015: FileNotFoundError('Could not fetch metrics for tune_model_59e62_00015: both result.json and progress.csv were not found at /home/kkisteman/MADS-MachineLearning-course/notebooks/4_tuning_networks/logs/test/tune_model_2025-10-18_15-14-17/tune_model_59e62_00015_15_hidden_size=128,num_layers=8_2025-10-18_15-14-17')
# - tune_model_59e62_00016: FileNotFoundError('Could not fetch metrics for tune_model_59e62_00016: both result.json and progress.csv were not found at /home/kkisteman/MADS-MachineLearning-course/notebooks/4_tuning_networks/logs/test/tune_model_2025-10-18_15-14-17/tune_model_59e62_00016_16_hidden_size=256,num_layers=8_2025-10-18_15-14-17')
# - tune_model_59e62_00017: FileNotFoundError('Could not fetch metrics for tune_model_59e62_00017: both result.json and progress.csv were not found at /home/kkisteman/MADS-MachineLearning-course/notebooks/4_tuning_networks/logs/test/tune_model_2025-10-18_15-14-17/tune_model_59e62_00017_17_hidden_size=512,num_layers=8_2025-10-18_15-14-17')
# 2025-10-18 15:14:40,910	WARNING experiment_analysis.py:558 -- Could not find best trial. Did you pass the correct `metric` parameter?
# 2025-10-18 15:14:40,913	WARNING experiment_analysis.py:558 -- Could not find best trial. Did you pass the correct `metric` parameter?
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 16
#      13 timer["ray_grid"] = time.time() - tic
#      15 best = analysis.get_best_config()
# ---> 16 best["accuracy"] = analysis.best_result["accuracy"]
#      17 best_config["grid"] = best
#
# File ~/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/tune/analysis/experiment_analysis.py:314, in ExperimentAnalysis.best_result(self)
#     307 if not self.default_metric or not self.default_mode:
#     308     raise ValueError(
#     309         "To fetch the `best_result`, pass a `metric` and `mode` "
#     310         "parameter to `tune.run()`. Alternatively, use "
#     311         "`get_best_trial(metric, mode).last_result` to set "
#     312         "the metric and mode explicitly and fetch the last result."
#     313     )
# --> 314 return self.best_trial.last_result
#
# AttributeError: 'NoneType' object has no attribute 'last_result'

# %%
import pandas as pd
all_results = pd.concat([all_results, analysis.results_df])

# %%
grid = analysis.results_df
plot_contour(grid, "config/hidden_size", "config/num_layers", "accuracy", start=0.7)

# %% [markdown]
# As you can see, we get a systematic scan, but large parts of the space are still unexplored, and we also explored parts that are really not very promising.

# %%
visualize.parallel_plot(analysis, columns)

# %%
visualize.plot_timers(timer)

# %% [markdown]
# # Bayes

# %% [markdown]
# Now, we improve the search algorithm with a bayesian optimization.
#
# Note that the bayesian search algorithm will only work with continuous parameters. This is a problem for the number of layers, which is a discrete parameter. I fixed this by simply casting the parameters to an integer inside the model, which is not very elegant but it works.

# %%
from ray.tune.search.bayesopt import BayesOptSearch

bayesopt = BayesOptSearch(metric="valid_loss", mode="min")


config = {
    "input_size": 3,
    "output_size": 20,
    "dropout": 0.1,
    "epochs": MAX_EPOCHS,
    "hidden_size": tune.uniform(16, 512),
    "num_layers": tune.uniform(1, 8),
    "tune_dir": tune_dir,
}

tic = time.time()

analysis = tune.run(
    tune_model,
    config=config,
    metric="valid_loss",
    mode="min",
    storage_path=str(tune_dir),
    num_samples=N_EXPERIMENTS,
    stop={"training_iteration": MAX_EPOCHS},
    search_alg=bayesopt,
    verbose=1,
)

timer["ray_bayes"] = time.time() - tic

best = analysis.get_best_config()
best["accuracy"] = analysis.best_result["accuracy"]
best_config["bayes"] = best

# %%
best

# %%
all_results = pd.concat([all_results, analysis.results_df])

# %%
bayes = analysis.results_df
plot_contour(bayes, "config/hidden_size", "config/num_layers", "accuracy", start=0.7)

# %% [markdown]
# As you can see, bayes really focuses on the promising areas. It is much more efficient than random search, and also more efficient than grid search.
# We have set the `random_search_steps` to 5, this means that we will do 5 random searches first, to get a good initial idea of the space. As you can see, 5 is a bit low, because it might lead to premature converging to a local optimum. You can increase this number to get a better initial idea of the space, but you will also need to increase the number of iterations after the initial random scan.

# %%
visualize.parallel_plot(analysis, columns)

# %%
visualize.plot_timers(timer)

# %%
import pandas as pd

pd.DataFrame.from_dict(best_config, orient="index")

# %% [markdown]
# # Hyperband
#
# Hyperband aborts runs early. Configs that are unpromising are abandoned before they complete.

# %%
from ray.tune.schedulers import AsyncHyperBandScheduler

scheduler = AsyncHyperBandScheduler(
    time_attr="training_iteration", grace_period=1, reduction_factor=3, max_t=MAX_EPOCHS
)

config = {
    "input_size": 3,
    "output_size": 20,
    "dropout": 0.1,
    "epochs": MAX_EPOCHS,
    "hidden_size": tune.randint(16, 512),
    "num_layers": tune.randint(1, 8),
    "tune_dir": tune_dir,
}

tic = time.time()
analysis = tune.run(
    tune_model,
    config=config,
    metric="valid_loss",
    mode="min",
    storage_path=str(tune_dir),
    num_samples=N_EXPERIMENTS,
    stop={"training_iteration": MAX_EPOCHS},
    scheduler=scheduler,
    verbose=1,
)

timer["ray_hyperband"] = time.time() - tic

best = analysis.get_best_config()
best["accuracy"] = analysis.best_result["accuracy"]
best_config["hyperband"] = best

# %% [markdown]
# If you study the iter column, you will see that some runs have been stopped early. This is exactly the point of hyperband: it tries to allocate resources to the most promising configurations.
#
# The downside of this, is that if you try to get a good view of the space, you get distorted results because comparing a model that has trained just 1 or 3 epochs with a model that has trained 100 epochs is not very fair...

# %%
all_results = pd.concat([all_results, analysis.results_df])

# %%
hyperband = analysis.results_df
plot_contour(hyperband, "config/hidden_size", "config/num_layers", "accuracy", start=0.7)

# %%
visualize.parallel_plot(analysis, columns)

# %% [markdown]
# But note that it is faster! This means you could do more runs in the same time, which might be a good tradeoff!
# Typically you will get better results if you scan the searchspace better by doing more runs, aborting the ones that are not promising and going on with the ones that seem to yield good results.

# %%
visualize.plot_timers(timer)

# %%
pd.DataFrame.from_dict(best_config, orient="index")

# %% [markdown]
# # Hyperbayes

# %% [markdown]
# It is possible to combine Hyperband with Bayesian optimization, implemented as `TuneBOHB` in ray.
# However, `TuneBOHB` in ray is dependent on `hpbandster`, which is not maintained anymore.
# Unfortunately, a dependency of `hpbandster` is `netifaces`, which is also not maintained anymore.
# While `netifaces` does work on some hardware, it fails to build on some other hardware, which is a problem.
#
# To still use BOHB type algoritms, I am planning to implement either SMAC3 or BEHB in the future.

# %% [markdown]
# # HyperOpt
# HyperOpt provides gradient/derivative-free optimization. They implemented TPE, which stands for Tree-structured Parzen Estimator. This is a bayesian optimization algorithm that uses a tree to model the distribution of the objective function. The main advantage is that TPE also works with discrete parameters and conditional search spaces which is a problem for the bayesian optimization.
#
# For example, you could do things like this:
# ```python
# conditional_space = {
#     "activation": hp.choice(
#         "activation",
#         [
#             {"activation": "relu", "mult": hp.uniform("mult", 1, 2)},
#             {"activation": "tanh"},
#         ],
#     ),
# }
# ```
#
# Where you have a discrete parameter `activation` that has a conditional parameter `mult`. This means that if you choose `relu`, you also need to set `mult`, but if you choose `tanh`, you do not need to set `mult`. See [documentation of ray](https://docs.ray.io/en/latest/tune/examples/hyperopt_example.html) for more details.

# %%
from ray.tune.search.hyperopt import HyperOptSearch
search = HyperOptSearch()

scheduler = AsyncHyperBandScheduler(
    time_attr="training_iteration", grace_period=1, reduction_factor=3, max_t=MAX_EPOCHS
)

# %%
config = {
    "input_size": 3,
    "output_size": 20,
    "dropout": 0.1,
    "epochs": MAX_EPOCHS,
    "hidden_size": tune.randint(16, 512),
    "num_layers": tune.randint(1, 8),
    "tune_dir": tune_dir,
}

tic = time.time()
analysis = tune.run(
    tune_model,
    config=config,
    metric="valid_loss",
    mode="min",
    storage_path=str(tune_dir),
    num_samples=N_EXPERIMENTS,
    stop={"training_iteration": MAX_EPOCHS},
    search_alg=search,
    scheduler=scheduler,
    verbose=1,
)

timer["ray_hyperopt"] = time.time() - tic

best = analysis.get_best_config()
best["accuracy"] = analysis.best_result["accuracy"]
best_config["hyperopt"] = best

# %%
all_results = pd.concat([all_results, analysis.results_df])

# %%
hyperbayes = analysis.results_df
plot_contour(hyperbayes, "config/hidden_size", "config/num_layers", "accuracy", start=0.3, size=0.05)

# %% [markdown]
# This model combines bayesian optimization with hyperband. This is a good idea, because it combines the efficiency of bayesian optimization with the speed of hyperband.

# %%
visualize.parallel_plot(analysis, columns)

# %%
visualize.plot_timers(timer)

# %%
pd.DataFrame.from_dict(best_config, orient="index")

# %%
contour = all_results[all_results["training_iteration"] == MAX_EPOCHS]
plot_contour(contour, "config/hidden_size", "config/num_layers", "accuracy", start=0.8)

# %%
stop = time.time() - start
print(stop)

# %%
if DELETE:
    import shutil
    shutil.rmtree(tune_dir)
